# %% [markdown]
# Importing the essential libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Loading the dataset

# %%
dataset = pd.read_csv("Bakery.csv")
dataset.head()
# Out:
#    TransactionNo          Items             DateTime  Daypart  DayType
# 0              1          Bread  2016-10-30 09:58:11  Morning  Weekend
# 1              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 2              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 3              3  Hot chocolate  2016-10-30 10:07:57  Morning  Weekend
# 4              3            Jam  2016-10-30 10:07:57  Morning  Weekend

# %%
print("Shape of Dataset: ",dataset.shape) # 20507 Rows and 5 Columns
# Out:
# Shape of Dataset:  (20507, 5)

# %%
dataset.describe(include=object)
# Out:
#          Items             DateTime    Daypart  DayType
# count    20507                20507      20507    20507
# unique      94                 9465          4        2
# top     Coffee  2017-02-17 14:18:20  Afternoon  Weekday
# freq      5471                   11      11569    12807

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20507 entries, 0 to 20506
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TransactionNo  20507 non-null  int64
#  1   Items          20507 non-null  object
#  2   DateTime       20507 non-null  object
#  3   Daypart        20507 non-null  object
#  4   DayType        20507 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 801.2+ KB

# %%
datetime = pd.to_datetime(dataset['DateTime'])
dataset['Day'] = datetime.dt.day_name()
dataset['Month'] = datetime.dt.month_name()
dataset['Year'] = datetime.dt.year
dataset.head()
# Out:
#    TransactionNo          Items             DateTime  Daypart  DayType  \
# 0              1          Bread  2016-10-30 09:58:11  Morning  Weekend
# 1              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 2              2   Scandinavian  2016-10-30 10:05:34  Morning  Weekend
# 3              3  Hot chocolate  2016-10-30 10:07:57  Morning  Weekend
# 4              3            Jam  2016-10-30 10:07:57  Morning  Weekend
#
#       Day    Month  Year
# 0  Sunday  October  2016
# 1  Sunday  October  2016
# 2  Sunday  October  2016
# 3  Sunday  October  2016
# 4  Sunday  October  2016

# %%
day_calc = dataset.groupby('Day')
day_freq = day_calc['Items'].count()
day_freq.sort_values(ascending=False)
# Out:
# Day
# Saturday     3554
# Friday       3266
# Sunday       3118
# Monday       3035
# Tuesday      2645
# Thursday     2601
# Wednesday    2288
# Name: Items, dtype: int64

# %%
month_calc = dataset.groupby('Month')
month_freq = month_calc['Items'].count()
month_freq.sort_values(ascending=False)
# Out:
# Month
# March        3220
# November     3076
# January      3027
# February     2748
# December     2647
# April        1048
# October      1041
# May           924
# July          741
# June          739
# August        700
# September     596
# Name: Items, dtype: int64

# %% [markdown]
# Preparing the data for Associate Rule Learning

# %%
transactions = list()

for i in dataset['TransactionNo'].unique():
    l = list(set(dataset[dataset['TransactionNo']==i]['Items']))
    transactions.append(l)

# %%
transactions[:10]
# Out:
# [['Bread'],
#  ['Scandinavian'],
#  ['Cookies', 'Jam', 'Hot chocolate'],
#  ['Muffin'],
#  ['Coffee', 'Pastry', 'Bread'],
#  ['Muffin', 'Pastry', 'Medialuna'],
#  ['Coffee', 'Pastry', 'Medialuna', 'Tea'],
#  ['Pastry', 'Bread'],
#  ['Muffin', 'Bread'],
#  ['Scandinavian', 'Medialuna']]

# %%
maxi = [0,len(transactions[0])]
for j in transactions:
    if len(j)>maxi[1]:
        maxi = [transactions.index(j),len(j)]

# %%
transactions.append(transactions[maxi[0]])
transactions[::-1]
# Out:
# [['Cookies',
#   'Chocolates',
#   'Tea',
#   'Mineral water',
#   'Tiffin',
#   'Coke',
#   'Coffee',
#   'Pastry',
#   'Juice',
#   'Alfajores'],
#  ['Smoothies'],
#  ['Coffee', 'Pastry'],
#  ['Tacos/Fajita', 'Coffee', 'Muffin', 'Tea'],
#  ['Truffles', 'Spanish Brunch', 'Christmas common', 'Tea'],
#  ['Bread'],
#  ['Spanish Brunch', 'Bread'],
#  ['Tacos/Fajita', 'Coffee', 'Toast'],
#  ['Tacos/Fajita', 'Coke'],
#  ['Sandwich', 'Smoothies'],
#  ['Coffee'],
#  ['Coffee', 'Spanish Brunch', 'Bread'],
#  ['Extra Salami or Feta', 'Coffee', 'Cookies'],
#  ['Bread'],
#  ['Farm House'],
#  ['Farm House'],
#  ['Bread', 'Tea'],
#  ['Sandwich', 'Bread'],
#  ['Coffee'],
#  ['Coffee', 'Spanish Brunch', 'Juice'],
#  ['Coffee', 'Bread'],
#  ['Bread'],
#  ['Cake', 'Juice', 'Tea'],
#  ['Coffee', 'Spanish Brunch', 'Extra Salami or Feta'],
#  ['Coffee'],
#  ['Coffee', 'Toast'],
#  ['Tea'],
#  ['Half slice Monster ', 'My-5 Fruit Shoot', 'Hot chocolate'],
#  ['Cake', 'Coffee'],
#  ['Baguette'],
#  ['Coffee', 'Pastry'],
#  ['Coffee', 'Pastry', 'Bread'],
#  ['Cake', 'Coffee', 'Medialuna', 'Hot chocolate'],
#  ['Vegan Feast'],
#  ['Vegan Feast'],
#  ['Vegan Feast'],
#  ['Scandinavian'],
#  ['Vegan Feast'],
#  ['Vegan Feast'],
#  ['Vegan Feast'],
#  ['Vegan Feast'],
#  ['Cake', 'Juice', 'Tea'],
#  ['Coffee', 'Scandinavian', 'Salad'],
#  ['Coffee', 'Muffin', 'Alfajores'],
#  ['Muffin', 'Bread'],
#  ['Sandwich', 'Coffee'],
#  ['Cake'],
#  ['Cake', 'Coffee', 'Soup'],
#  ['Brownie', 'Juice'],
#  ['Tea', 'Coffee', 'Alfajores'],
#  ['Cake', 'Coffee', 'Toast', 'Hot chocolate'],
#  ['Scandinavian'],
#  ['Honey'],
#  ['Cherry me Dried fruit', 'Eggs'],
#  ['Coffee'],
#  ['Truffles', 'Coke', 'Brownie'],
#  ['Scandinavian'],
#  ['Scandinavian', 'Bread'],
#  ['Cake', 'Coffee', 'Juice'],
#  ['Sandwich', 'Coffee', 'Bread'],
#  ['Cake', 'Honey', 'Tea', 'Tacos/Fajita', 'Coffee'],
#  ['Scandinavian'],
#  ['Tacos/Fajita', 'Bread'],
#  ['Tacos/Fajita', 'Juice'],
#  ['Tacos/Fajita', 'Juice', 'Tea'],
#  ['Scone', 'Coffee'],
#  ['The Nomad'],
#  ['Coffee', 'Brownie'],
#  ['Coffee'],
#  ['Jam', 'Bread'],
#  ['Bread'],
#  ['Truffles', 'Bread', 'Tacos/Fajita', 'Juice', 'Alfajores'],
#  ['Sandwich', 'Coffee', 'Juice'],
#  ['Cake'],
#  ['Truffles', 'Cake', 'Bread', 'Tacos/Fajita'],
#  ['Cake', 'Coffee', 'Bread', 'Tea'],
#  ['Coffee'],
#  ['Sandwich', 'Spanish Brunch', 'Juice', 'Tea'],
#  ['Tacos/Fajita', 'Coffee', 'Coke'],
#  ['Bread'],
#  ['Coffee'],
#  ['Sandwich'],
#  ['Bread'],
#  ['Muffin', 'Brownie'],
#  ['Coffee'],
#  ['Bread'],
#  ['The Nomad', 'Smoothies', 'Spanish Brunch', 'Tea', 'Coffee'],
#  ['Coffee'],
#  ['Scone', 'Coffee', 'Cookies', 'Bread'],
#  ['Tacos/Fajita', 'Coffee', 'Cake'],
#  ['Cake', 'Baguette', 'Christmas common', 'Scandinavian'],
#  ['Truffles', 'Coffee', 'Pastry'],
#  ['Scone', 'Coffee', 'Alfajores'],
#  ['Coffee'],
#  ['Pastry'],
#  ['Baguette'],
#  ['Truffles', 'Coffee', 'The Nomad'],
#  ['Argentina Night', 'Afternoon with the baker', 'Tea'],
#  ['Granola', 'Argentina Night', 'Afternoon with the baker', 'Tea'],
#  ['Bread'],
#  ['Sandwich', 'Coffee', 'Spanish Brunch', 'Bread'],
#  ['Coffee', 'Pastry'],
#  ['The Nomad', 'Spanish Brunch', 'Brownie', 'Cookies', 'Coffee'],
#  ['Coffee', 'Juice'],
#  ['Bread'],
#  ['Coffee', 'Muffin'],
#  ['Cake', 'Coffee', 'Alfajores'],
#  ['Bread'],
#  ['Coffee', 'Muffin', 'Bread'],
#  ['Baguette', 'Scandinavian', 'Bread'],
#  ['Farm House'],
#  ['Pastry'],
#  ['Bread'],
#  ['Coffee', 'Muffin', 'Baguette'],
#  ['Coffee', 'Salad', 'Extra Salami or Feta', 'Bread'],
#  ['Honey', 'Pastry', 'Bread'],
#  ['Bread'],
#  ['Cake', 'Coffee', 'Hot chocolate'],
#  ['Pastry', 'Alfajores'],
#  ['Bread'],
#  ['Argentina Night'],
#  ['Argentina Night'],
#  ['Coffee', 'Bread'],
#  ['Bread'],
#  ['Farm House'],
#  ['Pastry', 'Bread'],
#  ['Sandwich', 'Chicken Stew'],
#  ['Bread'],
#  ['Coffee', 'Alfajores'],
#  ['Coke'],
#  ['Scone', 'Coffee'],
#  ['Scone', 'Tea'],
#  ['Cake', 'Muffin', 'Alfajores'],
#  ['Cake', 'Tiffin', 'Bread'],
#  ['Cookies'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Sandwich', 'Mineral water'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Truffles', 'Chicken Stew'],
#  ['Tiffin', 'Tea'],
#  ['Cake',
#   'Truffles',
#   'Salad',
#   'Sandwich',
#   'Coke',
#   'Chicken Stew',
#   'Coffee',
#   'Juice',
#   'Alfajores'],
#  ['Coffee', 'Baguette', 'Bread'],
#  ['Bread'],
#  ['Coffee'],
#  ['Soup'],
#  ['Mineral water', 'Tea', 'Sandwich', 'Coke', 'Soup'],
#  ['Coffee'],
#  ['Coffee', 'Soup'],
#  ['Bread'],
#  ['Coffee', 'Toast'],
#  ['Coffee', 'Toast'],
#  ['Coffee', 'Toast'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Bread'],
#  ['Muffin', 'Juice', 'Tea'],
#  ['Coffee', 'Cookies'],
#  ['Cookies', 'Bread'],
#  ['Coffee', 'Pastry', 'Medialuna', 'Bread'],
#  ['Bread'],
#  ['Cake', 'Bread', 'Tea'],
#  ['Coffee'],
#  ['Coffee', 'Cookies', 'Bread'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee'],
#  ['Coffee', 'Tea'],
#  ['Toast', 'Cookies', 'Medialuna', 'Tiffin', 'Coffee'],
#  ['Pastry', 'Bread'],
#  ['Coffee'],
#  ['Cookies', 'Tea'],
#  ['Tiffin', 'Tea'],
#  ['Cake', 'Muffin', 'Bread', 'Mineral water'],
#  ['Bread', 'Alfajores'],
#  ['Coffee', 'Cookies', 'Juice'],
#  ['Coke'],
#  ['Sandwich', 'Coffee'],
#  ['Toast', 'Bread'],
#  ['Tiffin', 'Bread'],
#  ['Muffin', 'Soup', 'Bread', 'Tea'],
#  ['Coffee', 'Toast', 'Salad'],
#  ['Smoothies', 'Sandwich', 'Coke', 'Bread', 'Crisps', 'Coffee', 'Alfajores'],
#  ['Sandwich', 'Tea'],
#  ['Coffee'],
#  ['Truffles', 'Coffee', 'Tea'],
#  ['Sandwich', 'Coffee', 'Bread'],
#  ['Sandwich'],
#  ['Coffee', 'Tiffin'],
#  ['Coke', 'Soup', 'Farm House'],
#  ['Sandwich', 'Coffee'],
#  ['Coffee', 'Tiffin'],
#  ['Sandwich', 'Coffee'],
#  ['Muffin', 'Soup'],
#  ['Bread'],
#  ['Bread'],
#  ['Sandwich', 'Coffee'],
#  ['Coffee', 'Soup'],
#  ['Sandwich', 'Tea'],
#  ['Sandwich'],
#  ['Cookies', 'Art Tray', 'Juice', 'Salad'],
#  ['Coffee', 'Alfajores'],
#  ['Scandinavian', 'Farm House'],
#  ['Christmas common'],
#  ['Cake', 'Tea'],
#  ['Brioche and salami', 'Bread', 'Alfajores'],
#  ['Tea'],
#  ['Bread'],
#  ['Coffee', 'Toast'],
#  ['Tiffin', 'Juice', 'Tea'],
#  ['Coffee', 'Cookies', 'Juice', 'Bread'],
#  ['Coffee', 'Jammie Dodgers'],
#  ['Coffee', 'Juice'],
#  ['Coffee'],
#  ['Juice', 'Bread'],
#  ['Coffee', 'Toast'],
#  ['Farm House'],
#  ['Tea', 'Alfajores'],
#  ['Coffee', 'Tiffin', 'Bread'],
#  ['Coffee'],
#  ['Toast'],
#  ['Bread'],
#  ['Coffee'],
#  ['Juice', 'Mineral water'],
#  ['Cookies',
#   'Chocolates',
#   'Tea',
#   'Mineral water',
#   'Tiffin',
#   'Coke',
#   'Coffee',
#   'Pastry',
#   'Juice',
#   'Alfajores'],
#  ['Coffee', 'Pastry', 'Tea'],
#  ['Cake'],
#  ['Pastry'],
#  ['Tiffin', 'Bread'],
#  ['Bread'],
#  ['Cake', 'Tea'],
#  ['Cake', 'Coffee', 'Cookies', 'Bread'],
#  ['Coffee', 'Bread'],
#  ['Truffles', 'Cake', 'Bread'],
#  ['Spanish Brunch', 'Tea', 'Muffin', 'Cookies', 'Soup'],
#  ['Cake', 'Coffee'],
#  ['Cookies'],
#  ['Scandinavian'],
#  ['Coffee', 'Bread'],
#  ['Coke'],
#  ['Pastry'],
#  ['Baguette', 'Farm House'],
#  ['Jammie Dodgers', 'Bread'],
#  ['Baguette', 'Hot chocolate'],
#  ['Sandwich', 'Bread'],
#  ['Cake', 'Coffee', 'Hot chocolate'],
#  ['Cake', 'Tiffin', 'Sandwich', 'Coke', 'Juice'],
#  ['Cake', 'Cookies', 'Coffee'],
#  ['Sandwich', 'Coffee', 'Cake', 'Salad'],
#  ['Drinking chocolate spoons ', 'Bread'],
#  ['Cake'],
#  ['Coffee', 'Muffin', 'Extra Salami or Feta', 'Salad'],
#  ['Chicken Stew', 'Tiffin', 'Coke'],
#  ['Coffee', 'Tiffin', 'Bread'],
#  ['Coffee', 'Tea'],
#  ['Salad'],
#  ['Sandwich', 'Coffee'],
#  ['Sandwich', 'Coffee'],
#  ['Truffles', 'Coffee', 'Bread'],
#  ['Farm House'],
#  ['Pastry', 'Tea'],
#  ['Salad', 'Tea'],
#  ['Sandwich', 'Coffee', 'Tea'],
#  ['Coffee', 'Pastry'],
#  ['Tea', 'Muffin', 'Bread', 'Coffee', 'Pastry'],
#  ['Coffee', 'Toast', 'Bread'],
#  ['Coffee', 'Toast', 'Bread', 'Tea'],
#  ['Coffee', 'Pastry'],
#  ['Truffles', 'Tea'],
#  ['Bread'],
#  ['Coffee', 'Toast', 'Pastry'],
#  ['Tea'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Pastry', 'Hot chocolate'],
#  ['Coffee', 'Bread'],
#  ['Coffee'],
#  ['Bread', 'Jam', 'Christmas common', 'Hot chocolate'],
#  ['Bread', 'Tea'],
#  ['Coffee'],
#  ['Chicken Stew', 'Tea'],
#  ['Cake', 'Coffee', 'Smoothies', 'Tea'],
#  ['Cake', 'Coffee'],
#  ['Cake', 'Coffee', 'Juice', 'Tea'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Bread'],
#  ['Coffee', 'Salad'],
#  ['Coffee', 'Baguette'],
#  ['Coffee', 'Tea'],
#  ['Cookies', 'Mineral water'],
#  ['Coffee', 'Bread'],
#  ['Soup', 'Bread'],
#  ['Cake', 'Coffee'],
#  ['Cake', 'Coffee'],
#  ['Cake',
#   'Spanish Brunch',
#   'Salad',
#   'Bread',
#   'Coffee',
#   'Extra Salami or Feta',
#   'Juice'],
#  ['Soup', 'Tea'],
#  ['Cookies'],
#  ['Bread'],
#  ['Coffee', 'Salad'],
#  ['Coffee', 'Bread'],
#  ['Tea', 'Chicken Stew', 'Mineral water'],
#  ['Drinking chocolate spoons ',
#   'Mineral water',
#   'Salad',
#   'Sandwich',
#   'Coffee',
#   'Juice'],
#  ['Coffee'],
#  ['Coffee', 'Bread'],
#  ['Coffee', 'Extra Salami or Feta'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Juice', 'Bread'],
#  ['Bread'],
#  ['Coffee'],
#  ['Cake', 'Bread'],
#  ['Eggs'],
#  ['Coffee'],
#  ['Pastry', 'Bread'],
#  ['Coffee', 'Bread'],
#  ['Coffee', 'Jammie Dodgers', 'Bread'],
#  ['Honey', 'Jammie Dodgers', 'Bread'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Pastry'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coke'],
#  ['Tea'],
#  ['Pastry', 'Bread'],
#  ['Coffee', 'Extra Salami or Feta'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Cake', 'Pastry'],
#  ['Coffee', 'Toast'],
#  ['Coffee', 'Cookies'],
#  ['Bread', 'Mineral water'],
#  ['Coffee'],
#  ['Cake', 'Tea', 'Salad', 'Hot chocolate', 'Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Alfajores'],
#  ['Cookies'],
#  ['Coffee'],
#  ['Cookies', 'Tiffin', 'Hot chocolate'],
#  ['Coffee', 'Medialuna', 'Soup'],
#  ['Alfajores', 'Toast', 'Tea'],
#  ['Scone', 'Bread'],
#  ['Medialuna'],
#  ['Coffee', 'Alfajores', 'Tea'],
#  ['Cake', 'Cookies', 'Tea'],
#  ['Cookies', 'Tea'],
#  ['Sandwich', 'Bread'],
#  ['Soup'],
#  ['Cookies'],
#  ['Coffee', 'Jammie Dodgers', 'Juice'],
#  ['Coffee'],
#  ['Scone', 'Coffee', 'Bread'],
#  ['Sandwich', 'Coffee'],
#  ['Bread'],
#  ['Sandwich', 'Tea'],
#  ['Cake', 'Coffee', 'Medialuna'],
#  ['Coffee'],
#  ['Sandwich', 'Soup'],
#  ['Truffles', 'Scone', 'Coke', 'Mineral water'],
#  ['Coffee', 'Cookies'],
#  ['Scone', 'Spanish Brunch', 'Bread'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Toast', 'Farm House', 'Tea', 'Scandinavian', 'Coffee'],
#  ['Coffee', 'Toast'],
#  ['Sandwich', 'Coffee', 'Cake'],
#  ['Truffles'],
#  ['Bread'],
#  ['Cookies', 'Bread'],
#  ['Bread'],
#  ['The Nomad'],
#  ['Coffee', 'Coffee granules '],
#  ['Bread'],
#  ['Truffles', 'Coffee', 'Pastry', 'Bread'],
#  ['Coffee', 'Pastry'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Tea'],
#  ['Cake', 'Coffee', 'Pastry'],
#  ['Granola', 'Coffee', 'Toast'],
#  ['Scone', 'Bread'],
#  ['Sandwich', 'Coffee', 'Pastry'],
#  ['Coffee'],
#  ['Tea'],
#  ['Coffee'],
#  ['Coffee', 'Bread'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Cake', 'Cookies', 'Juice', 'Bread'],
#  ['Cake', 'Tea'],
#  ['Cookies'],
#  ['Cake', 'Coffee', 'Sandwich'],
#  ['Coffee', 'Spanish Brunch', 'Juice'],
#  ['Cake', 'Coffee'],
#  ['Sandwich', 'Coffee'],
#  ['Cake', 'Sandwich', 'Bread'],
#  ['Scone', 'Coffee', 'Bread', 'Tea'],
#  ['Truffles', 'Pastry', 'Bread'],
#  ['Cake'],
#  ['Cake', 'Smoothies'],
#  ['Soup'],
#  ['Argentina Night'],
#  ['Cake', 'Coffee'],
#  ['Scone', 'Cake', 'Pastry', 'Alfajores'],
#  ['Coffee', 'Pastry', 'Bread'],
#  ['Tea', 'Farm House', 'Muffin', 'Sandwich', 'Coke', 'Bread'],
#  ['Truffles', 'Sandwich', 'Crisps'],
#  ['Spanish Brunch'],
#  ['Sandwich', 'Coffee'],
#  ['Bread'],
#  ['Coffee', 'Jammie Dodgers', 'Juice', 'Tiffin'],
#  ['Bread'],
#  ['Fudge', 'Sandwich', 'Scandinavian', 'Bread', 'Coffee'],
#  ['Cake', 'Pastry'],
#  ['Bread', 'Farm House'],
#  ['Cake', 'Brownie'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee', 'Bread'],
#  ['Coffee', 'Cookies', 'Tea'],
#  ['Bread'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee'],
#  ['Coffee', 'Bread'],
#  ['Coffee', 'Muffin'],
#  ['Coffee', 'Pastry'],
#  ['Cake', 'Coffee', 'Hot chocolate'],
#  ['Cake', 'Coffee', 'Cookies'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread', 'Tiffin', 'Hot chocolate'],
#  ['Bread'],
#  ['Granola', 'Tea'],
#  ['Medialuna', 'Tea', 'Scone', 'Bread', 'Coffee'],
#  ['Coffee', 'Chicken Stew', 'Extra Salami or Feta'],
#  ['Bread'],
#  ['Sandwich'],
#  ['Coffee', 'Soup', 'Bread'],
#  ['Truffles', 'Spanish Brunch'],
#  ['Mineral water'],
#  ['Coffee'],
#  ['Bread'],
#  ['Cake', 'Brownie', 'Alfajores'],
#  ['Coffee'],
#  ['Scandinavian', 'Honey'],
#  ['Medialuna', 'Muffin', 'Sandwich', 'Bread', 'Coffee'],
#  ['Cake', 'Bread'],
#  ['Scone'],
#  ['Coffee', 'Soup', 'Bread'],
#  ['Bread'],
#  ['Cake', 'Cookies', 'Brownie', 'Coffee'],
#  ['Sandwich', 'Coffee', 'Truffles', 'Pastry'],
#  ['Coke', 'Soup'],
#  ['Chicken Stew', 'Soup', 'Tea'],
#  ['Truffles', 'Sandwich', 'Coke', 'Coffee', 'Pastry', 'Juice'],
#  ['Bread'],
#  ['Smoothies', 'Muffin', 'Sandwich', 'Bread', 'Coffee'],
#  ['Bread', 'Alfajores'],
#  ['The Nomad', 'Sandwich', 'Bread', 'Coffee', 'Juice'],
#  ['Brownie', 'Bread'],
#  ['The Nomad', 'Cake', 'Spanish Brunch', 'Tiffin', 'Coffee'],
#  ['Cake'],
#  ['Coffee', 'Tiffin'],
#  ['Cake', 'Coffee', 'Pastry', 'Tea'],
#  ['Coffee', 'Tea'],
#  ['Juice'],
#  ['Coffee'],
#  ['Coffee', 'Smoothies', 'Spanish Brunch', 'Bread'],
#  ['Bread'],
#  ['Crisps'],
#  ['Coffee'],
#  ['Pastry', 'Bread', 'Tea'],
#  ['Granola', 'Coffee'],
#  ['Bread'],
#  ['Baguette', 'Bread'],
#  ['The Nomad', 'Coffee'],
#  ['Coffee', 'Cookies'],
#  ['Medialuna', 'Truffles', 'Baguette', 'Coffee', 'Juice', 'Alfajores'],
#  ['Bread'],
#  ['Coffee', 'Toast', 'Juice'],
#  ['Coffee'],
#  ['Truffles', 'Coffee', 'Bread'],
#  ['Cake', 'Cookies', 'Bread'],
#  ['Coffee'],
#  ['Coffee', 'Pastry'],
#  ['Coffee', 'Cookies'],
#  ['Sandwich', 'Cookies', 'Brownie', 'Bread'],
#  ['Coffee granules '],
#  ['Scone', 'Coffee'],
#  ['Bread'],
#  ['Tiffin', 'Bread', 'Alfajores'],
#  ['Coffee'],
#  ['Pastry'],
#  ['Bread'],
#  ['Scone', 'Bread'],
#  ['Farm House'],
#  ['Juice'],
#  ['Coffee', 'Brownie', 'Cookies', 'Bread'],
#  ['Scone', 'Coffee', 'Toast', 'Coke'],
#  ['Cookies', 'Bread'],
#  ['Bread'],
#  ['Cake', 'Bread', 'Farm House'],
#  ['Sandwich', 'Cake', 'Bread'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Juice'],
#  ['Scone', 'Coffee', 'Coke', 'Soup'],
#  ['Coffee', 'Brownie'],
#  ['Coffee'],
#  ['Cookies', 'Bread'],
#  ['Coffee'],
#  ['Coffee', 'Tiffin'],
#  ['Cake', 'Hot chocolate'],
#  ['Pastry', 'Tea'],
#  ['Cake', 'Bread', 'Tea'],
#  ['Brownie', 'Tea'],
#  ['Scone', 'Bread'],
#  ['Cookies', 'Bread'],
#  ['Scone', 'Bread', 'Hot chocolate'],
#  ['Scone', 'Coffee'],
#  ['Scone', 'Coffee'],
#  ['Mineral water', 'Sandwich', 'Coke', 'Coffee', 'Soup'],
#  ['Coffee', 'Brownie'],
#  ['Chicken Stew', 'Soup', 'Bread'],
#  ['Tiffin', 'Bread'],
#  ['Coffee', 'Salad', 'Spanish Brunch', 'Extra Salami or Feta'],
#  ['Baguette'],
#  ['Tiffin'],
#  ['Sandwich', 'Coffee'],
#  ['Sandwich', 'Coffee', 'Bread'],
#  ['Sandwich', 'Bread'],
#  ['Chicken Stew'],
#  ['Cookies', 'Hot chocolate', 'Sandwich', 'Bread', 'Coffee'],
#  ['Bread'],
#  ['Tea', 'Salad', 'Baguette', 'Bread', 'Extra Salami or Feta'],
#  ['Brownie', 'Bread'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Muffin', 'Juice'],
#  ['Coffee'],
#  ['Coffee', 'Pastry'],
#  ['Coffee', 'Toast'],
#  ['Coffee'],
#  ['Bread'],
#  ['Cookies', 'Bread'],
#  ['Cookies', 'Bread'],
#  ['Cookies', 'Coke', 'Bread'],
#  ['Coffee', 'Alfajores'],
#  ['Coffee', 'Bread'],
#  ['Coffee', 'Bread'],
#  ['Spanish Brunch'],
#  ['Medialuna', 'Bread'],
#  ['Coffee'],
#  ['Cookies', 'Medialuna', 'Coffee', 'Juice', 'Alfajores'],
#  ['Coffee', 'Jammie Dodgers', 'Muffin', 'Juice'],
#  ['Farm House'],
#  ['Coffee', 'Medialuna'],
#  ['Bread'],
#  ['Cake'],
#  ['Bread'],
#  ['Coffee'],
#  ['Tiffin', 'Pastry', 'Hot chocolate', 'Tea'],
#  ['Tea'],
#  ['Cookies', 'Bread'],
#  ['Medialuna', 'Bread', 'Tea'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee', 'Toast'],
#  ['Coffee'],
#  ['Coffee', 'Tiffin'],
#  ['Coffee', 'Toast'],
#  ['Coffee'],
#  ['Sandwich', 'Coffee'],
#  ['Muffin'],
#  ['Coffee', 'Spanish Brunch', 'Juice', 'Bread'],
#  ['Cake', 'Tea'],
#  ['Cake', 'Coffee', 'Juice'],
#  ['Cake', 'Coffee'],
#  ['Sandwich', 'Coffee', 'Tea'],
#  ['Cake', 'Coffee', 'Tea'],
#  ['Sandwich', 'Coffee', 'Tea'],
#  ['Coffee'],
#  ['Bread'],
#  ['Cake', 'Coffee'],
#  ['Sandwich', 'Coffee', 'Toast', 'Tea'],
#  ['Cake', 'Coffee', 'Tea'],
#  ['Bread'],
#  ['Cake', 'Coffee', 'Tiffin', 'Bread'],
#  ['Cake', 'Coffee'],
#  ['Coffee', 'Toast'],
#  ['Truffles', 'Cookies', 'Soup'],
#  ['Sandwich', 'Coffee'],
#  ['Coffee', 'Extra Salami or Feta', 'Toast', 'Salad'],
#  ['Cake', 'Coke', 'Tea'],
#  ['Coffee', 'Chicken Stew'],
#  ['Cake', 'Juice', 'Sandwich'],
#  ['Salad'],
#  ['Cake', 'Truffles'],
#  ['Sandwich'],
#  ['Coffee', 'Bakewell'],
#  ['Cake', 'Tea', 'Truffles', 'Jammie Dodgers', 'Bread'],
#  ['Coffee', 'Muffin'],
#  ['Muffin', 'Juice', 'Hot chocolate'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Bread'],
#  ['Cake', 'Coffee', 'Baguette', 'Bread'],
#  ['Jammie Dodgers', 'Tiffin'],
#  ['Smoothies', 'Jammie Dodgers'],
#  ['Baguette', 'Bakewell'],
#  ['Bread'],
#  ['Coffee', 'Bread', 'Hot chocolate'],
#  ['Toast', 'Bread', 'Tea'],
#  ['Bread'],
#  ['Coffee'],
#  ['Cake', 'Tea'],
#  ['Coffee'],
#  ['Coffee', 'Cookies'],
#  ['Muffin', 'Bread'],
#  ['Bread'],
#  ['Mortimer'],
#  ['Coffee'],
#  ['Coffee', 'Toast', 'Hot chocolate'],
#  ['Christmas common'],
#  ['Christmas common'],
#  ['Christmas common'],
#  ['Coffee'],
#  ['Cake', 'Soup', 'Tea'],
#  ['Coffee', 'Jammie Dodgers'],
#  ['Tea'],
#  ['Juice'],
#  ['Coffee'],
#  ['Truffles', 'Coffee', 'Spanish Brunch'],
#  ['Coffee', 'Tiffin', 'Tea'],
#  ['Drinking chocolate spoons ', 'Coffee', 'Bread'],
#  ['Coffee', 'Muffin', 'Medialuna'],
#  ['Raw bars', 'Tea'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Spanish Brunch'],
#  ['Muffin', 'Bread'],
#  ['Scone', 'Coffee'],
#  ['Cake', 'Coffee', 'Soup', 'Tea'],
#  ['Bread'],
#  ['Cake', 'Soup', 'Tea'],
#  ['Bread'],
#  ['Sandwich', 'Coffee', 'Cookies', 'Tea'],
#  ['Coffee'],
#  ['Coffee', 'Chicken Stew', 'Soup', 'Bread'],
#  ['Art Tray', 'Coffee', 'Spanish Brunch', 'Juice'],
#  ['Bread'],
#  ['Cake', 'Coffee', 'Medialuna', 'Tea'],
#  ['Coffee'],
#  ['Coffee', 'Toast'],
#  ['Sandwich', 'Coke', 'Juice', 'Medialuna'],
#  ['Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee', 'Toast'],
#  ['Cake', 'Coffee', 'Bread'],
#  ['Coffee'],
#  ['Bread'],
#  ['Hot chocolate', 'Farm House'],
#  ['Smoothies'],
#  ['Granola'],
#  ['Spanish Brunch', 'Bread'],
#  ['Cookies', 'Juice', 'Tea'],
#  ['Bread'],
#  ['Bread', 'Cookies', 'Hot chocolate'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Salad'],
#  ['Cookies', 'Bread'],
#  ['Cookies', 'Muffin'],
#  ['Cookies', 'Bread'],
#  ['Coffee', 'Chicken Stew'],
#  ['Scone', 'Coffee'],
#  ['Cookies', 'Tea'],
#  ['Toast'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee', 'Toast', 'Muffin', 'Hot chocolate'],
#  ['Bread'],
#  ['Salad', 'Soup'],
#  ['Cake', 'Soup', 'Juice'],
#  ['Coffee', 'Muffin', 'Soup'],
#  ['Sandwich', 'Coffee'],
#  ['Muffin', 'Tea'],
#  ['Soup'],
#  ['Coffee', 'Soup'],
#  ['Sandwich', 'Tea'],
#  ['Sandwich', 'Tea'],
#  ['Sandwich', 'Mineral water'],
#  ['Toast', 'Bakewell', 'Sandwich', 'Bread', 'Juice'],
#  ['Sandwich', 'Toast', 'Coke', 'Mineral water'],
#  ['Cake', 'Muffin'],
#  ['Coffee', 'Bakewell', 'Soup'],
#  ['Sandwich', 'Coffee', 'Muffin', 'Coke'],
#  ['Eggs'],
#  ['Baguette', 'Bread'],
#  ['Truffles', 'Pastry', 'Bakewell'],
#  ['Coffee'],
#  ['Farm House'],
#  ['Coffee'],
#  ['Pastry'],
#  ['Coffee'],
#  ['Coffee', 'Pastry', 'Tea'],
#  ['Coffee', 'Pastry'],
#  ['Coffee', 'Cookies', 'Jammie Dodgers', 'Bakewell'],
#  ['Coffee', 'Pastry', 'Hot chocolate'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Cookies', 'Tea'],
#  ['Baguette'],
#  ['Coffee', 'Pastry'],
#  ['Coffee'],
#  ['Sandwich', 'Coffee'],
#  ['Coffee', 'Bakewell'],
#  ['Coffee'],
#  ['Coffee', 'Toast'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee', 'Bread'],
#  ['Coffee'],
#  ['Mineral water'],
#  ['Sandwich', 'Coffee'],
#  ['Tea'],
#  ['Cookies'],
#  ['Soup', 'Tea'],
#  ['Coffee', 'Bread'],
#  ['Muffin', 'Tea'],
#  ['Coffee'],
#  ['Sandwich', 'Coffee', 'Bakewell'],
#  ['Bakewell', 'Mineral water', 'Salad', 'Coke', 'Coffee'],
#  ['Coffee', 'Jammie Dodgers'],
#  ['Sandwich', 'Coffee', 'Coke'],
#  ['Coffee'],
#  ['Brownie', 'Tea', 'Jammie Dodgers', 'Sandwich', 'Chicken Stew', 'Bread'],
#  ['Bakewell'],
#  ['Bread'],
#  ['Coffee', 'Chicken Stew'],
#  ['Coffee'],
#  ['The Nomad', 'Coffee', 'Scone', 'Tea'],
#  ['Chicken Stew', 'Coke'],
#  ['Sandwich', 'Coffee'],
#  ['Coffee', 'Muffin', 'Coke'],
#  ['Brownie', 'Hot chocolate'],
#  ['Scone', 'Bakewell'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Coffee', 'Bread'],
#  ['Coffee'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Bread'],
#  ['Bread', 'Tea'],
#  ['Scone', 'Tea'],
#  ['Coffee', 'Muffin'],
#  ['Toast'],
#  ['Coffee'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Muffin'],
#  ['Toast', 'Hot chocolate'],
#  ['Toast', 'Tea'],
#  ['Bread'],
#  ['Coffee'],
#  ['Coffee', 'Muffin'],
#  ['Coffee', 'Bakewell'],
#  ['Sandwich', 'Juice', 'Bread'],
#  ['Brownie', 'Cookies', 'Hot chocolate', 'Bread', 'Coffee', 'Vegan Feast'],
#  ['Cake', 'Coffee', 'Brownie', 'Tea'],
#  ['Sandwich', 'Smoothies'],
#  ['Cake', 'Coffee'],
#  ['Muffin'],
#  ['Cake'],
#  ['Brownie', 'Tea', 'Sandwich', 'Bread', 'Coffee'],
#  ['Sandwich', 'Coke', 'Juice'],
#  ['Sandwich', 'Coffee'],
#  ['Brownie', 'Bread', 'Tea'],
#  ['Cake', 'Coffee', 'Brownie'],
#  ['Brownie'],
#  ['Coffee', 'Jammie Dodgers', 'Brownie', 'Hot chocolate'],
#  ['Coffee'],
#  ['Scone', 'Medialuna', 'Tea'],
#  ['Baguette'],
#  ['Bread'],
#  ['Sandwich', 'Coke', 'Juice', 'Mineral water'],
#  ['Sandwich', 'Tea'],
#  ['Cake', 'Coffee', 'Smoothies', 'Bread'],
#  ['Cake', 'Coke', 'Bread', 'Coffee', 'Soup'],
#  ['Smoothies'],
#  ['Bread'],
#  ['Bread'],
#  ['Baguette'],
#  ['Coffee', 'Brownie', 'Juice'],
#  ['Bread'],
#  ['Coffee', 'Spanish Brunch', 'Tea'],
#  ['Truffles', 'Toast'],
#  ['Cake', 'Spanish Brunch', 'Medialuna', 'Coffee', 'Juice'],
#  ['Bread'],
#  ['Bread'],
#  ['Smoothies', 'Bread'],
#  ['Baguette'],
#  ['Coffee'],
#  ['Coffee'],
#  ['Bread'],
#  ['Sandwich', 'Coffee', 'Pastry'],
#  ['Bread'],
#  ['Cake', 'Coffee'],
#  ['Coffee', 'Spanish Brunch', 'Toast', 'Extra Salami or Feta'],
#  ['Baguette', 'Bread'],
#  ['Cake', 'Coffee', 'Muffin', 'Tea'],
#  ['Coffee', 'Pastry', 'Bread'],
#  ['Coffee'],
#  ['Pastry'],
#  ['Bread'],
#  ['Bread'],
#  ['Coffee', 'Spanish Brunch', 'Juice'],
#  ['Cake', 'Spanish Brunch', 'Bread'],
#  ['Coffee'],
#  ['Bread', 'Jam'],
#  ['Muffin'],
#  ['Cake',
#   'Granola',
#   'Medialuna',
#   'Tea',
#   'Muffin',
#   'Hot chocolate',
#   'Sandwich',
#   'Bread',
#   'Coffee'],
#  ['Sandwich', 'Coffee', 'Medialuna'],
#  ['Coffee', 'Medialuna'],
#  ['Pastry'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee', 'Medialuna'],
#  ['Jam', 'Bread'],
#  ['Medialuna', 'Bread'],
#  ['Mortimer', 'Coffee granules '],
#  ['Cake', 'Coffee', 'Juice', 'Bread'],
#  ['Cake', 'Tea', 'Truffles', 'Muffin', 'Hot chocolate'],
#  ['Mineral water'],
#  ['Cookies', 'Jammie Dodgers', 'Bread'],
#  ['Bread'],
#  ['Bread'],
#  ['Cake', 'Coffee', 'Muffin'],
#  ['Truffles'],
#  ['Coffee', 'Tea'],
#  ['Cake', 'Coffee'],
#  ['Tea'],
#  ['The Nomad', 'Spanish Brunch', 'Chicken Stew', 'Coke', 'Coffee', 'Juice'],
#  ['Cake', 'Half slice Monster '],
#  ['Bread'],
#  ['Cake', 'Coffee', 'Smoothies', 'Bread'],
#  ['Cake', 'Hot chocolate'],
#  ['Sandwich', 'Coffee', 'Bread'],
#  ['Coffee', 'Salad'],
#  ['Coffee', 'Salad'],
#  ['Bread'],
#  ['Coffee', 'Muffin', 'Hot chocolate'],
#  ['Sandwich'],
#  ['Sandwich', 'Coffee'],
#  ['Coffee', 'Extra Salami or Feta', 'Salad'],
#  ['Bread'],
#  ['Cake', 'Coffee', 'Bread'],
#  ['Bread', 'Tea'],
#  ['Cake', 'Coke', 'Tea'],
#  ['Coffee'],
#  ['Bread'],
#  ['Coffee', 'Spanish Brunch'],
#  ['Cake'],
#  ['Coffee', 'Coke', 'Hot chocolate'],
#  ['Cake',
#   'Spanish Brunch',
#   'Truffles',
#   'Jammie Dodgers',
#   'Sandwich',
#   'Bread',
#   'Coffee'],
#  ['Smoothies', 'Spanish Brunch', 'Hot chocolate'],
#  ['Coffee', 'Pastry'],
#  ['Bread'],
#  ['Coffee', 'Bread'],
#  ['Mineral water'],
#  ['Cake', 'Coffee', 'Bread'],
#  ['Coffee', 'Spanish Brunch', 'Soup'],
#  ['Salad', 'Smoothies', 'Soup'],
#  ['Coke'],
#  ['Truffles', 'Soup', 'Mineral water'],
#  ['Coffee', 'Spanish Brunch', 'Juice', 'Tea'],
#  ['Coffee'],
#  ['Bread'],
#  ['Tea'],
#  ['Juice'],
#  ['Coffee', 'Salad'],
#  ['Bread'],
#  ['Sandwich', 'Coffee'],
#  ['Muffin'],
#  ['Cake', 'Juice', 'Bread'],
#  ['Cake', 'Coffee', 'Scandinavian'],
#  ['The Nomad'],
#  ['Bread'],
#  ['Scandinavian', 'Eggs'],
#  ['Cookies'],
#  ['Coffee'],
#  ['Cake', 'Bread'],
#  ['Smoothies', 'Muffin', 'Juice'],
#  ['Cookies', 'Muffin', 'Pastry'],
#  ['Scandinavian'],
#  ['Coffee', 'Spanish Brunch', 'Duck egg'],
#  ['Cake', 'Smoothies', 'Spanish Brunch', 'Muffin', 'Coffee', 'Pastry'],
#  ['Bread'],
#  ['Coffee', 'Muffin', 'Bread'],
#  ['Coffee granules ', 'Farm House'],
#  ['Cake', 'Coffee', 'Bread'],
#  ['Coffee', 'Pastry'],
#  ['Coffee', 'Tiffin', 'Bread'],
#  ['Cookies', 'Hot chocolate', 'Scandinavian', 'Bread', 'Coffee'],
#  ['Coffee', 'Pastry', 'Juice'],
#  ['Coffee'],
#  ['Muffin', 'Pastry', 'Bread'],
#  ['Coffee', 'Jammie Dodgers', 'Cookies', 'Juice'],
#  ['Coffee', 'Spanish Brunch'],
#  ['Coffee'],
#  ['Bread'],
#  ['Bread'],
#  ['Pastry', 'Bread'],
#  ['Bread'],
#  ['Cake', 'Coffee'],
#  ['Bread'],
#  ['Scandinavian'],
#  ['Drinking chocolate spoons ', 'Muffin', 'Hot chocolate', 'Bread', 'Pastry'],
#  ['Cookies', 'Jammie Dodgers', 'Pastry'],
#  ['Cake', 'Scandinavian', 'Muffin', 'Baguette'],
#  ['Coffee', 'Muffin'],
#  ['Pastry', 'Bread'],
#  ['Scandinavian', 'Bread'],
#  ['Jammie Dodgers', 'Tea'],
#  ['Baguette', 'Farm House'],
#  ['Pastry'],
#  ['Cookies', 'Farm House'],
#  ['Pastry', 'Bread'],
#  ['Coffee'],
#  ['Cake', 'Pastry', 'Bread'],
#  ['Farm House'],
#  ['Coffee', 'Spanish Brunch', 'Juice', 'Bread'],
#  ['Coffee', 'Toast'],
#  ['Coffee', 'Baguette'],
#  ['Coffee'],
#  ['Bread'],
#  ['Truffles', 'Tea'],
#  ['Truffles', 'Coffee', 'Tiffin'],
#  ['Cake', 'Coffee'],
#  ['Cake', 'Coffee', 'Bread'],
#  ['Cookies', 'Juice', 'Tea'],
#  ['Eggs', 'Bread'],
#  ['Cake', 'Bread', 'Tea'],
#  ['Coffee', 'Brownie'],
#  ['Cake', 'Coffee', 'Juice'],
#  ['Spanish Brunch', 'Baguette'],
#  ['Coffee', 'Toast'],
#  ['Jam'],
#  ['Truffles', 'Mineral water'],
#  ['Spanish Brunch', 'Bread'],
#  ['Truffles', 'Coffee', 'Soup', 'Sandwich'],
#  ['Cake', 'Cookies', 'Coffee'],
#  ['Cake', 'Muffin'],
#  ['Coffee'],
#  ['Cake', 'Toast', 'Hot chocolate', 'Sandwich', 'Coffee', 'Soup'],
#  ['Sandwich', 'Coffee'],
#  ['Bread'],
#  ['Salad'],
#  ['Coffee', 'Spanish Brunch'],
#  ['Chicken Stew', 'Bread'],
#  ['Tiffin', 'Chicken Stew', 'Bread'],
#  ['Muffin', 'Bread'],
#  ['Coffee'],
#  ['Cookies', 'Bread'],
#  ['Bread'],
#  ['Tiffin', 'Bread'],
#  ['Coffee', 'Brownie'],
#  ['Bread'],
#  ['Coffee', 'Pastry'],
#  ['Baguette'],
#  ['Cake', 'Coffee', 'Bread'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Pastry', 'Bread'],
#  ['Coffee'],
#  ['Coffee', 'Muffin', 'Bread'],
#  ['Coffee', 'Scandinavian', 'Cookies'],
#  ['Scandinavian', 'Pastry', 'Bread'],
#  ['Coffee'],
#  ['Spanish Brunch', 'Bread'],
#  ['Coffee', 'Juice'],
#  ['Baguette', 'Bread'],
#  ['Coffee'],
#  ['Pastry', 'Tea'],
#  ['Coffee', 'Tiffin'],
#  ['Coffee', 'Tea'],
#  ['Coffee'],
#  ['Pastry', 'Bread'],
#  ['Baguette'],
#  ['Coffee', 'Farm House'],
#  ['Coffee', 'Medialuna'],
#  ['Coffee'],
#  ['Coffee', 'Tea'],
#  ['Coffee', 'Cookies', 'Brownie'],
#  ['Mortimer'],
#  ['Coffee', 'Smoothies', 'Tiffin'],
#  ...]

# %% [markdown]
# Using Apriori Model for this Recommendation System

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))

# %%
from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.0001, min_confidence=0.2,min_lift=3,min_length=2,max_length=2)
print("Done with the training of apriori")
results = list(rules)
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])
print(resultsinDataFrame)
# Out:
# Done with the training of apriori
#   Left Hand Side Right Hand Side   Support  Confidence      Lift
# 0           Coke        Sandwich  0.005176    0.264865  3.687075
# 1  Mineral water        Sandwich  0.003275    0.229630  3.196580
